# %%
import pickle

with open("Results/resnet20_cifar10_SNOWS_1:4_k=40_results.pickle", "rb") as f:
    data = pickle.load(f)

print(data)
# Out:
# {'accuracies': [92.59, 92.35, 92.11, 91.68, 90.82, 90.21, 89.66, 87.14, 81.98, 74.74, 74.74], 'losses': [0.2815192461013794, 0.2906973473727703, 0.2996278077363968, 0.31210344582796096, 0.3479639858007431, 0.37236524671316146, 0.3976011112332344, 0.4975149124860764, 0.630213950574398, 0.8299643725156785], 'total_time': 1451.8228514194489}
